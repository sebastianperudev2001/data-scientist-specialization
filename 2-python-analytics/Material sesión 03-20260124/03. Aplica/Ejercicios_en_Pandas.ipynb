# %% [markdown]
# #  Ejercicios  con Pandas en Python

# %%
import pandas as pd
import numpy as np

# Datos ejemplo
data = {
    'id': range(1, 11),
    'nombre': ['Ana', 'Luis', 'Juan', 'Ana', 'Pedro', 'Luis', 'Juan', 'Ana', 'Pedro', 'Luis'],
    'edad': [25, 32, np.nan, 40, 29, 32, 36, np.nan, 29, 30],
    'ventas': [100, 200, 150, 120, 300, 210, np.nan, 180, 310, 220],
    'ciudad': ['Madrid', 'Barcelona', 'Madrid', 'Valencia', 'Madrid', 'Barcelona', 'Madrid', 'Valencia', 'Madrid', 'Barcelona']
}

df = pd.DataFrame(data)
df

# %% [markdown]
# ## 🔍 1-5: Filtros

# %%
# 1. Filtrar personas mayores de 30 años

# %%
# 2. Filtrar ventas mayores a 200 y ciudad = 'Madrid'

# %%
# 3. Filtrar filas con nombre 'Ana'

# %%
# 4. Filtrar filas con edad nula

# %%
# 5. Filtrar donde nombre sea 'Luis' o 'Pedro'

# %% [markdown]
# ## 📊 6-10: Agrupaciones

# %%
# 6. Promedio de ventas por ciudad

# %%
# 7. Cantidad de registros por nombre

# %%
# 8. Suma de ventas por nombre y ciudad

# %%
# 9. Edad máxima por nombre

# %%
# 10. Contar valores nulos por columna

# %% [markdown]
# ## 🔗 11-13: Merge / Join

# %%
df_extra = pd.DataFrame({
    'nombre': ['Ana', 'Luis', 'Juan', 'Pedro'],
    'departamento': ['Ventas', 'Marketing', 'IT', 'Ventas']
})
df_extra

# %%
# 11. Unir por nombre (left join)

# %%
# 12. Inner join para obtener solo coincidencias

# %% [markdown]
# ## 🧼 13-15: Imputaciones , limpieza y pivot

# %%
# 13. Imputar edad con la media

# %%
# 14. Eliminar filas con valores nulos

# %%
# 15. Pivot table: promedio de ventas por ciudad y nombre

# %% [markdown]
# ## 🧪 16-20: Ejercicios adicionales de Pandas

# %%
# 16. Reemplazar valores 'Luis' por 'Luis Miguel'

# %%
# 17. Ordenar por ventas descendente

# %%
# 18. Contar cuántas veces aparece cada ciudad

# %%
# 19. Crear una columna booleana si las ventas son mayores a 200

# %%
# 20. Mostrar primeros 5 registros únicos por nombre
